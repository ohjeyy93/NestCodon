# %%
import subprocess
from subprocess import check_output
import csv
import itertools
import numpy as np

# %%
## create dummy file to write down all the strains
file="testnew.txt"

# %%
## open the dummy file
f = open(file, "w")
subprocess.run(['ls', '/home/momo/Desktop/CDC/MaRSnew/NeSTcodon5/output/'], stdout=f)
# Out:
# CompletedProcess(args=['ls', '/home/momo/Desktop/CDC/MaRSnew/NeSTcodon5/output/'], returncode=0)

# %%
## extract all the strains from the bam file
f = open(file, "r")
file2="testnewrevised.txt"
f2 = open(file2, "w")
for line in f:
    #print(line.strip('\n').split("_S",1)[0])
    if line.strip('\n')!="nest.log":
        #print((line.strip('\n').split("_S",1)[0]))
        f2.write(line.strip('\n').split("_S",1)[0])
        f2.write('\n')

# %%
filename = "codondepthstat1-3-2.csv"

# %%
f2 = open(file, "r")

# %%
## create a list of strains

dictionary={}
strainList=[]
count=0
for line in f2:
    count+=1
    strainList+=["codon"+str(count)]
    strainList+=[line.strip('\n').split("_S",1)[0]]
    dictionary[line.strip('\n').split("_S",1)[0]]=line.strip('\n')

#print(dictionary)

# %%
## open csv file
with open(filename, 'w') as csvfile: 
    csvwriter = csv.writer(csvfile) 
    csvwriter.writerow(strainList) 
    #csvwriter.writerows(rows)

# %%
## setup initial count, depth, and codon
countofnucleotide=0
sumOfDepth=0
currentCodon=""
currentcodonnum=1
file3="textnew.txt"
k = open(file3, "w")

f2 = open(file2, "r")

# %%
def getValue(x):
    a,_,b = x.partition(" ")
    if not b.isdigit():
        return (float("inf"), x)
    return (a, int(b))

# %%
### create list of codon depth for each strains
WholeCodonlist=[] ###codon list for whole strains
Codonlistname=[]  ## name of strains 
Codonsamplenum=0  ## codons for different strains
currentGeneList=[]
CurrentCodonList=[]
fileN="testnewrevised.txt"
fN=open(fileN, "r")
samplelist=[]
for line in fN:
    samplelist+=[line.strip('\n')]

#print(samplelist)
WholeCodonPosNameList=[]

f2 = open(file2, "r")

for line in f2:
    #print(line)
    #print('/home/momo/Desktop/CDC/DhruviPatel-Haiti_Test_bam/Haiti_Test_bam/'+line.strip('\n')+'/alignments/output_FM_SR_DD_RG.bam')
    #out=check_output(['samtools', 'depth', '-a', '/home/momo/Desktop/CDC/DhruviPatel-Haiti_Test_bam/Haiti_Test_bam/'+line.strip('\n')+'/alignments/output_FM_SR_DD_RG.bam'])
    file3=line.strip('\n')+"textnew.txt"
    k = open(file3, "w")
    ## run samtools to obtain depth of each nucleotide base
    #print(line.strip('\n').split("_S",1)[0
    #print(line)
    if line.strip('\n') in samplelist:
        #print("working")
        #print(line.strip('\n'))
        subprocess.run(['samtools', 'depth', '-a', '/home/momo/Desktop/CDC/MaRSnew/NeSTcodon5/output/'+dictionary[line.strip('\n')]+'/alignments/output_FM_SR_DD_RG.bam'], stdout=k)
        k2 = open(file3, "r")
        #print(k2)
        countofnucleotide=0
        sumOfDepth=0
        currentCodon=""
        #CurrentCodonList=[]
        #Codonsamplenum+=1
        currentCodonPos=0
        currentGene=line.strip('\n')

        for line in k2:
            if int((line.split()[2])) > 10:
                currentCodon=(line.split()[0])
                currentCodonPos=int(line.split()[1])//3+1
                sumOfDepth+=int((line.split()[2]))
                break
                ## update the codon position and depth

        for line in k2:
            #print(line)
            #line.split()[2]
            if int(line.split()[1])%3>0:
                ## operation for same codon
                if currentCodonPos==int(line.split()[1])//3+1:
                    currentCodon=(line.split()[0])
                    sumOfDepth+=int(line.split()[2])
                    #print(currentCodon, currentCodonPos)
                elif currentCodonPos!=int(line.split()[1])//3+1:
                    currentCodon=(line.split()[0])
                    sumOfDepth=0
                    sumOfDepth+=int(line.split()[2])
                    currentCodonPos=int(line.split()[1])//3+1
            elif int(line.split()[1])%3==0:
                ## operation when codon is done
                currentCodon=(line.split()[0])
                #print(currentCodon)
                sumOfDepth+=int(line.split()[2])
                countofnucleotide=1
                currentCodonPos=int(line.split()[1])//3
                #testname=currentCodon+"codon"+str(currentCodonPos)
                #print(testname)
                if sumOfDepth>10:
                    #print(currentCodon)
                    if currentCodon=="PfDHFR":
                        if 606<=currentCodonPos<=609:
                            if currentCodon+"codon"+str(currentCodonPos) not in WholeCodonPosNameList:
                                WholeCodonPosNameList+=[currentCodon+"codon"+str(currentCodonPos)]
                    elif currentCodon=="PfMDR1":
                        if 1263<=currentCodonPos<=1420:
                            if currentCodon+"codon"+str(currentCodonPos) not in WholeCodonPosNameList:
                                WholeCodonPosNameList+=[currentCodon+"codon"+str(currentCodonPos)]
                    #CurrentCodonList+=[sumOfDepth]
                    #currentGeneList+=[currentGene]
                sumOfDepth=0
                #print(currentCodon, currentCodonPos)
        #print(Codonlistname)
        #if Codonsamplenum==1:
        #    ## operation for first strain
        #    WholeCodonlist+=[Codonlistname]
        #    WholeCodonlist+=[CurrentCodonList]
        #else:
            ## operation for next strain
            #WholeCodonlist+=[Codonlistname]
    #WholeCodonPosNameList+=[Codonlistname]
    #Codonlistname=[]

#for item in WholeCodonPosNameList:
#    print(item)
    
#print(WholeCodonPosNameList)
#wr1=["sample"]
#wr1+=sorted(WholeCodonPosNameList, key=getValue)
#with open(filename, 'w') as csvfile: 
#    csvwriter = csv.writer(csvfile) 
#    csvwriter.writerow(wr1)

# %%
#to test if output is good
#for item in sorted(WholeCodonPosNameList, key=getValue):
#    print(item)
#    with open(filename, 'w') as csvfile: 
#        csvwriter = csv.writer(csvfile) 
#        csvwriter.writerow(item)
#for item in WholeCodonPosNameList:
#    print(item)

# %%
## setup initial count, depth, and codon
countofnucleotide=0
sumOfDepth=0
currentCodon=""
currentcodonnum=1
file3="textnew.txt"
k = open(file3, "w")

f2 = open(file2, "r")

### create list of codon depth for each strains
WholeCodonlist=[] ###codon list for whole strains
Codonlistname=[]  ## name of strains 
Codonsamplenum=0  ## codons for different strains
currentGeneList=[]
CurrentCodonList=[]

fileN="testnewrevised.txt"
fN=open(fileN, "r")
samplelist=[]
for line in fN:
    #print(line)
    samplelist+=[line.strip('\n')]

for line in f2:
    #print(line)
    #print('/home/momo/Desktop/CDC/DhruviPatel-Haiti_Test_bam/Haiti_Test_bam/'+line.strip('\n')+'/alignments/output_FM_SR_DD_RG.bam')
    #out=check_output(['samtools', 'depth', '-a', '/home/momo/Desktop/CDC/DhruviPatel-Haiti_Test_bam/Haiti_Test_bam/'+line.strip('\n')+'/alignments/output_FM_SR_DD_RG.bam'])
    file3=line.strip('\n')+"textnew.txt"
    k = open(file3, "w")
    ## run samtools to obtain depth of each nucleotide base
    #print(line.strip('\n').split("_S",1)[0
    #print(line)
    if line.strip('\n') in samplelist:
        #print("working")
        #print(line.strip('\n'))
        #print(dictionary[line.strip('\n')])
        #print(line.strip('\n'))
        subprocess.run(['samtools', 'depth', '-a', '/home/momo/Desktop/CDC/MaRSnew/NeSTcodon5/output/'+dictionary[line.strip('\n')]+'/alignments/output_FM_SR_DD_RG.bam'], stdout=k)
        k2 = open(file3, "r")
        #print(k2)
        countofnucleotide=0
        sumOfDepth=0
        currentCodon=""
        #CurrentCodonList=[]
        #Codonsamplenum+=1
        currentCodonPos=0
        currentGene=line.strip('\n')

        ## sum the depth of nucleotide base untill 3 of them is covered for each codon
        ## set up initial codon and codon position for the loop
        for line in k2:
            #print(line)
            currentCodon=(line.split()[0])
            currentCodonPos=int(line.split()[1])//3+1
            sumOfDepth+=int((line.split()[2]))
            #print(currentCodon)
            break
        #print(currentCodon)
        ## update the codon position and depth
        
        for line in k2:
            #print(line)
            #line.split()[2]
            if int(line.split()[1])%3>0:
                ## operation for same codon
                if currentCodonPos==int(line.split()[1])//3+1:
                    currentCodon=(line.split()[0])
                    sumOfDepth+=int(line.split()[2])
                    #print(currentCodon, currentCodonPos)
                elif currentCodonPos!=int(line.split()[1])//3+1:
                    currentCodon=(line.split()[0])
                    sumOfDepth=0
                    sumOfDepth+=int(line.split()[2])
                    currentCodonPos=int(line.split()[1])//3+1
            elif int(line.split()[1])%3==0:
                ## operation when codon is done
                currentCodon=(line.split()[0])
                #print(currentCodon)
                sumOfDepth+=int(line.split()[2])
                countofnucleotide=1
                currentCodonPos=int(line.split()[1])//3
                #testname=currentCodon+"codon"+str(currentCodonPos)
                #print(testname)
                if sumOfDepth>10:
                    #print("working")
                    Codonlistname+=[currentCodon+"codon"+str(currentCodonPos)]
                    CurrentCodonList+=[sumOfDepth]
                    currentGeneList+=[currentGene]
                sumOfDepth=0
                #print(currentCodon, currentCodonPos)
        #print(Codonlistname)
        #if Codonsamplenum==1:
        #    ## operation for first strain
        #    WholeCodonlist+=[Codonlistname]
        #    WholeCodonlist+=[CurrentCodonList]
        #else:
            ## operation for next strain
            #WholeCodonlist+=[Codonlistname]
WholeCodonlist+=[Codonlistname]
WholeCodonlist+=[CurrentCodonList]
WholeCodonlist+=[currentGeneList]

#print(len(WholeCodonlist[0]))
#print(len(WholeCodonlist[1]) )     

print(WholeCodonlist[1])

itemlist=[]
numlist=[]
meainglist=[]
for item in WholeCodonPosNameList:
    mean1=0
    min1=0
    max1=0
    thridquant1=0
    listnum=[]
    for x in range(len(WholeCodonlist[0])):
        #print(x)
        #print(item)
        if item == WholeCodonlist[0][x]:
            listnum+=[WholeCodonlist[1][x]]
    #print(listnum)
    print(item)
    min1=np.nanmin(listnum)
    max1=np.nanmax(listnum)
    mean1=np.mean(listnum)
    thridquant1=np.quantile(listnum, 0.75)
    itemlist+=[item]
    numlist+=[mean1]
    meainglist+=["mean"]
    itemlist+=[item]
    numlist+=[min1]
    meainglist+=["min"]
    itemlist+=[item]
    numlist+=[max1]
    meainglist+=["max"]
    itemlist+=[item]
    numlist+=[thridquant1]
    meainglist+=["thirdquant"]
    

completelist=[]

completelist+=[itemlist]
completelist+=[numlist]
completelist+=[meainglist]
# Out:
# [21, 36, 45, 54, 54, 54, 60, 60, 60, 68, 72, 76, 78, 78, 78, 78, 90, 90, 90, 113, 147, 165, 181, 214, 226, 235, 273, 271, 273, 276, 298, 325, 334, 338, 336, 338, 336, 336, 336, 334, 330, 326, 325, 320, 307, 270, 264, 256, 246, 246, 237, 227, 222, 213, 201, 163, 116, 91, 84, 76, 63, 60, 70, 86, 92, 91, 74, 73, 75, 75, 75, 77, 94, 115, 131, 135, 139, 144, 144, 144, 141, 136, 142, 133, 112, 102, 105, 105, 124, 142, 147, 150, 148, 162, 188, 193, 204, 199, 207, 211, 216, 215, 223, 222, 218, 222, 233, 234, 241, 246, 242, 240, 237, 231, 235, 239, 230, 229, 228, 217, 216, 216, 216, 218, 228, 227, 226, 234, 275, 278, 291, 322, 362, 359, 358, 360, 360, 358, 358, 368, 372, 378, 390, 390, 390, 392, 395, 399, 390, 394, 380, 369, 363, 355, 361, 359, 360, 360, 368, 368, 372, 368, 371, 389, 382, 398, 416, 425, 415, 429, 432, 438, 438, 441, 442, 446, 446, 447, 453, 453, 466, 477, 489, 501, 492, 475, 480, 474, 464, 444, 448, 459, 457, 425, 399, 393, 388, 388, 378, 367, 357, 349, 312, 299, 283, 298, 294, 284, 230, 152, 154, 172, 173, 183, 197, 196, 231, 248, 310, 389, 423, 460, 483, 488, 494, 513, 513, 518, 528, 548, 600, 609, 663, 684, 694, 757, 766, 797, 826, 839, 844, 828, 845, 855, 871, 875, 891, 895, 891, 901, 906, 938, 958, 1042, 1025, 1023, 1003, 987, 959, 946, 938, 932, 923, 916, 929, 953, 959, 936, 943, 915, 881, 870, 870, 852, 800, 777, 756, 748, 729, 718, 711, 708, 699, 650, 616, 561, 528, 471, 394, 375, 348, 331, 326, 324, 314, 302, 304, 292, 236, 180, 139, 84, 56, 43, 38, 38, 56, 60, 60, 60, 60, 57, 57, 57, 57, 53, 51, 50, 47, 43, 38, 46, 54, 62, 58, 48, 46, 51, 55, 57, 57, 57, 61, 67, 75, 75, 81, 93, 101, 119, 127, 129, 131, 135, 135, 158, 167, 172, 178, 182, 210, 213, 247, 304, 321, 347, 391, 500, 536, 549, 555, 547, 544, 556, 591, 656, 664, 658, 662, 679, 709, 703, 690, 678, 675, 655, 647, 635, 621, 615, 607, 589, 576, 578, 574, 553, 542, 516, 518, 537, 526, 503, 443, 448, 456, 432, 369, 372, 375, 371, 342, 322, 312, 532, 645, 647, 635, 615, 613, 615, 620, 622, 613, 600, 553, 477, 390, 249, 179, 181, 183, 189, 183, 181, 182, 194, 191, 188, 187, 201, 204, 213, 229, 233, 237, 238, 230, 223, 217, 175, 259, 271, 275, 272, 268, 262, 257, 264, 282, 272, 259, 294, 297, 306, 313, 314, 309, 310, 315, 338, 313, 303, 305, 302, 302, 316, 315, 308, 305, 309, 312, 310, 308, 303, 302, 285, 285, 285, 287, 286, 273, 266, 278, 280, 266, 262, 258, 318, 354, 379, 357, 360, 372, 375, 375, 380, 410, 406, 405, 404, 409, 456, 470, 487, 537, 562, 553, 533, 531, 552, 585, 589, 590, 698, 768, 818, 884, 930, 914, 905, 922, 930, 930, 930, 926, 941, 929, 961, 993, 1035, 1012, 1029, 1042, 1090, 1002, 877, 871, 893, 891, 879, 882, 892, 894, 881, 869, 825, 802, 801, 799, 796, 781, 773, 768, 764, 758, 742, 738, 739, 813, 784, 721, 739, 687, 651, 600, 592, 581, 590, 600, 577, 575, 601, 600, 599, 617, 635, 678, 718, 708, 725, 736, 718, 712, 742, 757, 749, 744, 741, 734, 729, 725, 749, 733, 716, 714, 707, 698, 681, 666, 653, 652, 627, 626, 582, 573, 549, 530, 525, 510, 502, 523, 520, 521, 551, 558, 532, 476, 474, 476, 480, 476, 480, 488, 488, 485, 486, 487, 493, 505, 513, 512, 510, 469, 517, 519, 519, 515, 478, 480, 469, 459, 483, 489, 498, 477, 471, 468, 479, 500, 523, 540, 556, 540, 543, 555, 558, 550, 552, 550, 558, 548, 517, 499, 429, 425, 407, 397, 393, 399, 393, 391, 384, 378, 390, 398, 368, 297, 274, 269, 269, 277, 284, 272, 271, 264, 274, 309, 329, 323, 302, 314, 296, 271, 275, 275, 273, 288, 289, 298, 306, 302, 298, 312, 314, 314, 309, 311, 327, 331, 345, 353, 361, 365, 370, 380, 380, 376, 373, 369, 399, 417, 417, 417, 445, 463, 480, 498, 492, 488, 479, 475, 479, 480, 486, 486, 496, 506, 480, 454, 446, 437, 413, 399, 390, 369, 359, 348, 309, 302, 284, 293, 284, 231, 199, 196, 184, 179, 191, 266, 345, 404, 410, 424, 440, 450, 461, 459, 459, 473, 475, 492, 513, 526, 528, 533, 530, 528, 536, 552, 552, 550, 556, 605, 658, 671, 721, 698, 692, 691, 677, 676, 667, 638, 654, 628, 611, 597, 598, 588, 589, 555, 561, 537, 484, 465, 442, 440, 432, 430, 397, 382, 381, 3 ...
# PfDHFRcodon606
# PfDHFRcodon607
# PfDHFRcodon608
# PfDHFRcodon609
# PfMDR1codon1263
# PfMDR1codon1264
# PfMDR1codon1265
# PfMDR1codon1266
# PfMDR1codon1267
# PfMDR1codon1268
# PfMDR1codon1269
# PfMDR1codon1270
# PfMDR1codon1271
# PfMDR1codon1272
# PfMDR1codon1273
# PfMDR1codon1274
# PfMDR1codon1275
# PfMDR1codon1276
# PfMDR1codon1277
# PfMDR1codon1278
# PfMDR1codon1279
# PfMDR1codon1280
# PfMDR1codon1281
# PfMDR1codon1282
# PfMDR1codon1283
# PfMDR1codon1284
# PfMDR1codon1285
# PfMDR1codon1286
# PfMDR1codon1287
# PfMDR1codon1288
# PfMDR1codon1289
# PfMDR1codon1290
# PfMDR1codon1291
# PfMDR1codon1292
# PfMDR1codon1293
# PfMDR1codon1294
# PfMDR1codon1295
# PfMDR1codon1296
# PfMDR1codon1297
# PfMDR1codon1298
# PfMDR1codon1299
# PfMDR1codon1300
# PfMDR1codon1301
# PfMDR1codon1302
# PfMDR1codon1303
# PfMDR1codon1304
# PfMDR1codon1305
# PfMDR1codon1306
# PfMDR1codon1307
# PfMDR1codon1308
# PfMDR1codon1309
# PfMDR1codon1310
# PfMDR1codon1311
# PfMDR1codon1312
# PfMDR1codon1313
# PfMDR1codon1314
# PfMDR1codon1315
# PfMDR1codon1316
# PfMDR1codon1317
# PfMDR1codon1318
# PfMDR1codon1319
# PfMDR1codon1320
# PfMDR1codon1321
# PfMDR1codon1322
# PfMDR1codon1323
# PfMDR1codon1324
# PfMDR1codon1325
# PfMDR1codon1326
# PfMDR1codon1327
# PfMDR1codon1328
# PfMDR1codon1329
# PfMDR1codon1330
# PfMDR1codon1331
# PfMDR1codon1332
# PfMDR1codon1333
# PfMDR1codon1334
# PfMDR1codon1335
# PfMDR1codon1336
# PfMDR1codon1337
# PfMDR1codon1338
# PfMDR1codon1339
# PfMDR1codon1340
# PfMDR1codon1341
# PfMDR1codon1342
# PfMDR1codon1343
# PfMDR1codon1344
# PfMDR1codon1345
# PfMDR1codon1346
# PfMDR1codon1347
# PfMDR1codon1348
# PfMDR1codon1349
# PfMDR1codon1350
# PfMDR1codon1351
# PfMDR1codon1352
# PfMDR1codon1353
# PfMDR1codon1354
# PfMDR1codon1355
# PfMDR1codon1356
# PfMDR1codon1357
# PfMDR1codon1358
# PfMDR1codon1359
# PfMDR1codon1360
# PfMDR1codon1361
# PfMDR1codon1362
# PfMDR1codon1363
# PfMDR1codon1364
# PfMDR1codon1365
# PfMDR1codon1366
# PfMDR1codon1367
# PfMDR1codon1368
# PfMDR1codon1369
# PfMDR1codon1370
# PfMDR1codon1371
# PfMDR1codon1372
# PfMDR1codon1373
# PfMDR1codon1374
# PfMDR1codon1375
# PfMDR1codon1376
# PfMDR1codon1377
# PfMDR1codon1378
# PfMDR1codon1379
# PfMDR1codon1380
# PfMDR1codon1381
# PfMDR1codon1382
# PfMDR1codon1383
# PfMDR1codon1384
# PfMDR1codon1385
# PfMDR1codon1386
# PfMDR1codon1387
# PfMDR1codon1388
# PfMDR1codon1389
# PfMDR1codon1390
# PfMDR1codon1391
# PfMDR1codon1392
# PfMDR1codon1393
# PfMDR1codon1394
# PfMDR1codon1395
# PfMDR1codon1396
# PfMDR1codon1397
# PfMDR1codon1398
# PfMDR1codon1399
# PfMDR1codon1400
# PfMDR1codon1401
# PfMDR1codon1402
# PfMDR1codon1403
# PfMDR1codon1404
# PfMDR1codon1405
# PfMDR1codon1406
# PfMDR1codon1407
# PfMDR1codon1408
# PfMDR1codon1409
# PfMDR1codon1410
# PfMDR1codon1411

# %%
################################################
filename2 = "codondepthstat1-3-2.csv"
with open(filename2, 'w') as csvfile2: 
    csvwriter = csv.writer(csvfile2) 
    csvwriter.writerow(["item", "stats", "meaning"])
    #print(np.transpose(WholeCodonlist))
    #print(len(WholeCodonlist[0]))
    #print(len(WholeCodonlist[1]))
    #print(len(WholeCodonlist[15]))
    #print(list(zip(*WholeCodonlist)))
    #print(*zip(*WholeCodonlist))
    #WholeCodonListTranspose=list(map(list, zip(*WholeCodonlist)))
    #print(WholeCodonListTranspose)
    #for list in np.transpose(WholeCodonlist):
    #    print(list)
    #    csvwriter.writerow(list)
    #    break
    csvwriter.writerows(list(itertools.zip_longest(*completelist, fillvalue="")))
    #csvwriter.writerows((zip(*np.transpose(WholeCodonlist))))
